# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Christian**
# Data Scientist

# %% [markdown]
# _I am interested in data science because I want to overcome limitations I have as a data analyst_

# %% [markdown]
# ### The summation of my age and my wife's

# %%
32+28
# Out:
# 60

# %% [markdown]
# ______________________________
#
# ![Capture.PNG](attachment:Capture.PNG)
#
# ~~The above is the Data science logo~~
# ______________________________
